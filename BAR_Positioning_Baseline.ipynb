# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !wget "https://zenodo.org/records/15239874/files/all.zip"

# %%
# Crei la cartella se non esiste
# !mkdir -p "/content/drive/My Drive/Tesi Magistrale/"

# Ora copi il file
# !cp all.zip "/content/drive/My Drive/Tesi Magistrale/"

# %%
# !unzip all.zip

# %%
# !pip install -r requirements.txt

# %%
# Entriamo nella cartella di lavoro
# %cd train

# Eseguiamo l'esperimento salvando i risultati direttamente su Drive
# !python main.py \
  --train ../data/fingerprints/android_session_1_1.csv \
  --test ../data/fingerprints/android_session_2_2.csv \
  --algorithm knn \
  --k 57 \
  --output-prefix "/content/drive/My Drive/Tesi Magistrale/risultati_BAR_1_2_57NN_"

# %%
# Eseguiamo l'intera suite di esperimenti per k=1 e k=57
# !python run_experiments.py --data-dir ../data/fingerprints --k-values 1 57

# %%
# Copiamo i due file riassuntivi più importanti sul nostro Drive
# Assicurati che la cartella "Tesi Magistrale" esista!

# !cp results/all_experiments.csv "/content/drive/My Drive/Tesi Magistrale/"
# !cp results/latex_table.tex "/content/drive/My Drive/Tesi Magistrale/"
